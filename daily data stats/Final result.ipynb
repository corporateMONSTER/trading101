# %%
import pandas as pd
import numpy as np
import statistics

# %%
df=pd.read_excel('C:/Users/jayasuriya/Desktop/mission stocks/all data/Final data.xlsx')

# %%
df.head(5)
# Out:
#         Date  ADANIPORTS  ASIANPAINT  AXISBANK  BAJAJ-AUTO  BAJAJFINSV  \
# 0 2021-10-12      736.90     3323.25    797.15     3978.75    18222.65
# 1 2021-10-11      737.45     3306.05    787.15     3852.10    17713.95
# 2 2021-10-08      739.90     3306.90    781.95     3815.55    17549.45
# 3 2021-10-07      736.15     3290.85    777.10     3828.55    17470.25
# 4 2021-10-06      724.00     3212.25    778.95     3770.05    17616.60
#
#    BAJFINANCE  BHARTIARTL    BPCL  BRITANNIA  ...      PEL  PETRONET  \
# 0     7855.75      686.35  455.25    3867.95  ...  2791.00    236.20
# 1     7817.10      690.85  454.40    3840.60  ...  2754.35    230.35
# 2     7732.20      695.50  449.45    3883.30  ...  2736.25    227.80
# 3     7747.90      692.50  449.20    3900.60  ...  2888.20    230.40
# 4     7735.15      691.40  447.20    3938.60  ...  2842.15    230.25
#
#    PIDILITIND    PNB      UBL  TORNTPHARM  SIEMENS  SBICARD      PGHH  \
# ...

# %%
df.shape
# Out:
# (250, 99)

# %%
cols=df.columns
cols=cols[1:-1]
print(cols)
# Out:
# Index(['ADANIPORTS', 'ASIANPAINT', 'AXISBANK', 'BAJAJ-AUTO', 'BAJAJFINSV',
#        'BAJFINANCE', 'BHARTIARTL', 'BPCL', 'BRITANNIA', 'CIPLA', 'COALINDIA',
#        'DIVISLAB', 'DRREDDY', 'EICHERMOT', 'GRASIM', 'HCLTECH', 'HDFC',
#        'HDFCBANK', 'HDFCLIFE', 'HEROMOTOCO', 'HINDALCO', 'HINDUNILVR',
#        'ICICIBANK', 'INDUSINDBK', 'INFY', 'IOC', 'ITC', 'JSWSTEEL',
#        'KOTAKBANK', 'LT', 'M&M', 'MARUTI', 'NESTLEIND', 'NTPC', 'ONGC',
#        'POWERGRID', 'RELIANCE', 'SBILIFE', 'SBIN', 'SHREECEM', 'SUNPHARMA',
#        'TATACONSUM', 'TATAMOTORS', 'TATASTEEL', 'TCS', 'TECHM', 'TITAN',
#        'ULTRACEMCO', 'UPL', 'WIPRO', 'ABBOTINDIA', 'ACC', 'ADANIENT', 'ALKEM',
#        'AMBUJACEM', 'APOLLOHOSP', 'AUROPHARMA', 'BAJAJHLDNG', 'BANDHANBNK',
#        'BERGEPAINT', 'BIOCON', 'BOSCHLTD', 'CADILAHC', 'COLPAL', 'DABUR',
#        'DLF', 'DMART', 'GAIL', 'GODREJCP', 'HDFCAMC', 'HINDPETRO', 'ICICIGI',
#        'HAVELLS', 'ICICIPRULI', 'IGL', 'INDIGO', 'INDUSTOWER', 'YESBANK',
# ...

# %%
df_dict={}
for col in cols:
    rt=[]
    for i in range(len(df[col])-1):
        num=df[col].iloc[i+1]
        den=df[col].iloc[i]
        val=np.log(num/den)
        val_final=val*100
        rt.append(val_final)

    average=statistics.mean(rt)
    std=statistics.stdev(rt)
    df_dict[col]=[(df[col][0]*np.exp((average+std)/100)),(df[col][0]*np.exp((average-std)/100)),(df[col][0]*np.exp((average+(2*std))/100)),(df[col][0]*np.exp((average-(2*std))/100)),(df[col][0]*np.exp((average+(3*std))/100)),(df[col][0]*np.exp((average-(3*std))/100))]

# %%
# statistics.mean(rt)

# %%
# for i in range(len(rt)):
#     rt[i]=rt[i]*100

# %%
# len(rt)

# %%
# tot=0
# length=len(rt)
# for i in rt:
#     tot=tot+i
# print(tot/length)

# %%
df_dict
# Out:
# {'ADANIPORTS': [753.4613669374224,
#   716.5300926614494,
#   772.6348023301297,
#   698.7489321479152,
#   792.2961467794787,
#   681.4090227031722],
#  'ASIANPAINT': [3373.998201919828,
#   3260.9417184644376,
#   3431.987929667194,
#   3205.8421300250006,
#   3490.974340970081,
#   3151.6735501433072],
#  'AXISBANK': [811.4684340733438,
#   779.7415653882723,
#   827.8127345051473,
#   764.3463801336156,
#   844.4862358588696,
#   749.2551567806273],
#  'BAJAJ-AUTO': [4037.557193375116,
#   3912.15475644278,
#   4101.757849397467,
#   3850.9217653578767,
#   4166.9793514503,
#   3790.6471921860248],
#  'BAJAJFINSV': [18545.374856185765,
#   17744.393925901586,
#   18959.32359198168,
#   17356.971379023482,
#   19382.512020002523,
#   16978.00762935515],
#  'BAJFINANCE': [7999.661545517289,
#   7661.377074339066,
#   8174.364524905643,
#   7497.637691659637,
#   8352.882807083186,
#   7337.397756296285],
#  'BHARTIARTL': [697.6883240704733,
#   672.4736022471252,
# ...

# %%
# statistics.stdev(rt)

# %%
df_final=pd.DataFrame.from_dict(df_dict, orient='index')

# %%
df_final=df_final.round()

# %%
df_final.columns=["Upper 1","Lower 1","Upper 2","Lower 2","upper 3","lower 3"]

# %%
df_final.head()
# Out:
#             Upper 1  Lower 1  Upper 2  Lower 2  upper 3  lower 3
# ADANIPORTS    753.0    717.0    773.0    699.0    792.0    681.0
# ASIANPAINT   3374.0   3261.0   3432.0   3206.0   3491.0   3152.0
# AXISBANK      811.0    780.0    828.0    764.0    844.0    749.0
# BAJAJ-AUTO   4038.0   3912.0   4102.0   3851.0   4167.0   3791.0
# BAJAJFINSV  18545.0  17744.0  18959.0  17357.0  19383.0  16978.0

# %%
df_final.to_excel("volatility.xlsx")

# %%
# df_dict["ADANIPORTS"]

# %%
# df["ADANIPORTS"][0]
